# %%
import pandas as pd
import random

domains = {
    "Engineering": {
        "count": 20,
        "exam": "GATE",
        "degrees": ["B.Tech", "B.E"],
        "subjects": ["Mathematics", "Programming", "Data Structures"],
        "desc": "Advanced study in engineering principles, computational methods, and applied technology."
    },
    "Management": {
        "count": 10,
        "exam": "CAT",
        "degrees": ["BBA", "B.Com", "B.Tech", "BA"],
        "subjects": ["Mathematics", "Economics", "Statistics"],
        "desc": "Comprehensive training in business strategy, leadership, finance, and organizational management."
    },
    "Science": {
        "count": 12,
        "exam": "CUET-PG",
        "degrees": ["B.Sc"],
        "subjects": ["Mathematics", "Physics", "Chemistry"],
        "desc": "In-depth exploration of scientific theories, laboratory methods, and analytical reasoning."
    },
    "Humanities": {
        "count": 8,
        "exam": "NONE",
        "degrees": ["BA"],
        "subjects": ["History", "Political Science", "Sociology"],
        "desc": "Critical study of society, culture, philosophy, and human behavior across contexts."
    },
    "PhD": {
        "count": 10,
        "exam": "NET",
        "degrees": ["M.Tech", "MBA", "M.Sc", "MA"],
        "subjects": ["Research Methods", "Domain Knowledge"],
        "desc": "Original research leading to scholarly contribution in the chosen academic discipline."
    }
}
